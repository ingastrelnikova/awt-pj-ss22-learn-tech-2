# %%
# pip install spacy
# python -m spacy download de_core_news_lg
import pandas as pd
import spacy
sp = spacy.load('de_core_news_lg')

# %%
skills = pd.read_csv('./data/competencies/skills_de.csv')
skills.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13891 entries, 0 to 13890
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   conceptType     13891 non-null  object
#  1   conceptUri      13891 non-null  object
#  2   skillType       13890 non-null  object
#  3   reuseLevel      13891 non-null  object
#  4   preferredLabel  13891 non-null  object
#  5   altLabels       2928 non-null   object
#  6   hiddenLabels    32 non-null     object
#  7   status          13891 non-null  object
#  8   modifiedDate    13891 non-null  object
#  9   scopeNote       0 non-null      float64
#  10  definition      0 non-null      float64
#  11  inScheme        13891 non-null  object
#  12  description     13891 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 1.4+ MB

# %%
skills['preferredLabel']
# Out:
# 0                                  Musikpersonal verwalten
# 1                    Strafvollzugsverfahren beaufsichtigen
# 2                  nicht unterdrückende Praktiken anwenden
# 3        Einhaltung von Vorschriften von Eisenbahnfahrz...
# 4                             verfügbare Dienste ermitteln
#                                ...
# 13886    berufliche Leistungsfähigkeit von Nutzern/Nutz...
# 13887             Beleuchtung in Transportgeräten einbauen
# 13888                     Verarbeitung natürlicher Sprache
# 13889                             Bauarbeiten koordinieren
# 13890         Absturzsicherungen und Bordbretter anbringen
# Name: preferredLabel, Length: 13891, dtype: object

# %%
skill_labels = skills['preferredLabel'].copy(deep=True)
termStore = {}
URI = 0
for i,sequence in enumerate(skill_labels):
    sequence = sp(sequence)
    label = ''
    for term in sequence:
        if term.is_alpha and not term.is_stop:
            term = term.lemma_
            label += term + ' '
            if termStore.get(term) == None: 
                termStore[term] = URI
                URI += 1
        skill_labels[i] = label

# %%
skill_labels
# Out:
# 0                                 musikpersonal verwalten
# 1                     Strafvollzugsverfahr beaufsichtigen
# 2                          unterdrückend Praktik anwenden
# 3        Einhaltung Vorschrift Eisenbahnfahrzeuge überp...
# 4                              verfügbar Dienst ermitteln
#                                ...
# 13886    beruflich Leistungsfähigkeit Nutzer Nutzerinn ...
# 13887                 Beleuchtung Transportgerät einbauen
# 13888                      Verarbeitung natürlich Sprache
# 13889                              Bauarbeit koordinieren
# 13890              Absturzsicherung Bordbretter anbringen
# Name: preferredLabel, Length: 13891, dtype: object

# %%
termStore
# Out:
# {'musikpersonal': 0,
#  'verwalten': 1,
#  'Strafvollzugsverfahr': 2,
#  'beaufsichtigen': 3,
#  'unterdrückend': 4,
#  'Praktik': 5,
#  'anwenden': 6,
#  'Einhaltung': 7,
#  'Vorschrift': 8,
#  'Eisenbahnfahrzeuge': 9,
#  'überprüfen': 10,
#  'verfügbar': 11,
#  'Dienst': 12,
#  'ermitteln': 13,
#  'toxikologisch': 14,
#  'Studie': 15,
#  'durchführen': 16,
#  'Einheitlichkeit': 17,
#  'Kokille': 18,
#  'gewährleisten': 19,
#  'Haskell': 20,
#  'Initiative': 21,
#  'zeigen': 22,
#  'Personal': 23,
#  'Blick': 24,
#  'Verringerung': 25,
#  'Lebensmittelabfäll': 26,
#  'schulen': 27,
#  'Grundsatz': 28,
#  'Diplomatie': 29,
#  'polizeilich': 30,
#  'Ermittlung': 31,
#  'leiten': 32,
#  'Abfall': 33,
#  'Fischernt': 34,
#  'umgehen': 35,
#  'Energiesparkonzept': 36,
#  'entwickeln': 37,
#  'Streetworker': 38,
#  'tätig': 39,
#  'Solist': 40,
#  'Solistinn': 41,
#  'arbeiten': 42,
#  'Bewegungsmedizin': 43,
#  'Pflanzenforschung': 44,
#  'Wärmepumpe': 45,
#  'installieren': 46,
# ...

# %%
sequenceStore = {}
for sequence in skill_labels:
    URI = []
    sequence = sp(sequence[:-1])
    for term in sequence:
        URI.append(termStore[str(term)])
    sequenceStore[tuple(URI)] = str(sequence)

# %%
for key in sequenceStore.keys():
    if termStore['Verfahren'] in key:
        print(sequenceStore[key])
# Out:
# Verfahren Kontrolle gefährlich Stoff Rahmen Gesundheitsvorschrifte befolgen
# Verfahren Frachtoperationen planen
# Verfahren Erfüllung Vorschrift Hubschrauberflug durchführen
# Entwicklung außenpolitisch Strategie Verfahren
# Verfahren automatisiert Migration entwickeln
# Formel Verfahren umsetzen
# Verfahren Holzbearbeitung
# verschieden Flugnavigationsbereichen verbunden Verfahren
# veterinärmedizinisch Verfahren assistieren
# Verfahren Herstellung Lederwaren
# Verfahren Technik Herstellung Schuhen gezwickt Machart
# Kraftstoffpreise Einklang unternehmensintern Verfahren anpassen
# Verfahren Reinigung Beleuchtungsanlag Flughafen anwenden
# Verfahren Vorfertigung Schuhunterteile anwenden
# Verfahren anwenden Fracht Zollbestimmung entsprechen
# Verfahren Genesung Tier
# Prozeß Verfahren Schuhwerk Lederwaren Vorbereitung Nähprozess
# bildgebend Verfahren
# Verfahren maschinell Schneiden Schuhwerk Lederwaren anwenden
# bewährt Verfahren Tochterunternehmen teilen
# ...

# %%
sequenceStore[(293,294,295,296,297,298,299)]
# Out:
# 'Verfahren Kontrolle gefährlich Stoff Rahmen Gesundheitsvorschrifte befolgen'
